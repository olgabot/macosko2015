# %% [markdown]
# # Extract data from Supplementary Excel files
#
# The purpose of this notebook is to extract data from the Excel files, clean them, and write them to CSV.

# %%
import os
import common

# Assign notebook and folder names
notebook_name = '04_extract_data_from_supplementary_excel_files'
figure_folder = os.path.join(common.FIGURE_FOLDER, notebook_name)
data_folder = os.path.join(common.DATA_FOLDER, notebook_name)
print('Figure folder:', figure_folder)
print('Data folder:', data_folder)

# Make the folders
! mkdir -p $figure_folder
! mkdir -p $data_folder
# Out:
# Figure folder: ../figures/04_extract_data_from_supplementary_excel_files
# Data folder: ../data/04_extract_data_from_supplementary_excel_files

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
input_folder = os.path.join(common.DATA_FOLDER, '00_original')

# %%
ls $input_folder
# Out:
# GSM1544798_SpeciesMix_ThousandSTAMPs_HUMAN.digital_expression.txt.gz
# GSM1544798_SpeciesMix_ThousandSTAMPs_MOUSE.digital_expression.txt.gz
# GSM1544799_SpeciesMix_HundredSTAMPs_HUMAN.digital_expression.txt.gz
# GSM1544799_SpeciesMix_HundredSTAMPs_MOUSE.digital_expression.txt.gz
# GSM1626793_P14Retina_1.digital_expression.txt.gz
# GSM1626794_P14Retina_2.digital_expression.txt.gz
# GSM1626795_P14Retina_3.digital_expression.txt.gz
# GSM1626796_P14Retina_4.digital_expression.txt.gz
# GSM1626797_P14Retina_5.digital_expression.txt.gz
# GSM1626798_P14Retina_6.digital_expression.txt.gz
# GSM1626799_P14Retina_7.digital_expression.txt.gz
# GSM1629192_Pure_HumanMouse_HUMAN.digital_expression.txt.gz
# GSM1629192_Pure_HumanMouse_MOUSE.digital_expression.txt.gz
# GSM1629193_ERCC.digital_expression.txt.gz
# GSM1629193_hg19_ERCC.dict.txt.gz
# GSM1629193_hg19_ERCC.refFlat.txt.gz
# mmc1.pdf
# mmc2.xlsx
# mmc3.xlsx
# mmc4.xlsx
# mmc4_v2.xlsx
# retina_clusteridentities.txt
# ~$mmc4_v2.xlsx

# %% [markdown]
# ## Cluster markers
#
# These are the genes that were preferentially expressed in individual clusters, according to their analysis.
#
#
# The original supplementary file was corrupted and had many problems with the column values so I fixed them by hand, which is why we use `mmc4_v2.xlsx`.

# %%
filename = os.path.join(input_folder, 'mmc4_v2.xlsx')

cluster_markers = pd.read_excel(filename,
                                sheetname='FINAL_MARKERS_FOR_EACH_CLUSTER.',
                                skiprows=3)
cluster_markers = cluster_markers.rename(columns={"Unnamed: 0": 'gene_symbol'})

# Remove any rows with NA because those are all header rows
print(cluster_markers.shape)
cluster_markers = cluster_markers.dropna(subset=['gene_symbol', 'cluster #'])
print(cluster_markers.shape)
cluster_markers['cluster #'] = cluster_markers['cluster #'].astype(int)
cluster_markers.head()
# Out:
# (4292, 5)
# (4140, 5)
#   gene_symbol  myAUC    myDiff  power  cluster #
# 0       CALB1  0.966  3.615047  0.466          1
# 1      SLC4A3  0.963  3.448571  0.463          1
# 2        TPM3  0.965  3.151521  0.465          1
# 3       SEPT4  0.964  2.939258  0.464          1
# 4         VIM  0.944  2.937992  0.444          1

# %%
cluster_markers.groupby('gene_symbol').size()
# Out:
# gene_symbol
# 1500015O10RIK      1
# 1500016L03RIK      1
# 1700025G04RIK      1
# 1810009A15RIK      1
# 1810037I17RIK      1
# 2010107E04RIK      1
# 2410066E13RIK      1
# 2610017I09RIK      2
# 2900011O08RIK     11
# 4632428N05RIK      1
# 4833424O15RIK      4
# 4930447C04RIK      3
# 6330403K07RIK      7
# 6430548M08RIK     11
# 8430419L09RIK      1
# A030009H04RIK     13
# A330050F15RIK      1
# A730046J19RIK      2
# A830010M20RIK      2
# A830036E02RIK      1
# A930001A20RIK      1
# A930011O12RIK      7
# ABAT               2
# ABCA8A             1
# ABCB1A             1
# ABCC9              1
# ABCG2              1
# ABHD10             1
# ABHD2              1
# ABHD4              1
#                   ..
# WFDC1              1
# WFDC10             1
# WIPI1              1
# WLS                2
# WNK4               1
# WWTR1              1
# YWHAB              1
# YWHAB    0.253     1
# YWHAG              5
# YWHAH              6
# YWHAQ              1
# ZBTB20             1
# ZCCHC12            1
# ZCCHC18            4
# ZCCHC18    0.7     1
# ZEB2               5
# ZFHX3              5
# ZFHX4              2
# ZFP36              1
# ZFP365             1
# ZFP36L1            2
# ZFP804A            5
# ZFP804A    0.7     1
# ZFP804A 0.710      1
# ZFP804A 0.714      1
# ZIC1               1
# ZIC4               1
# ZMAT4              2
# ZWINT              6
# ZYX                1
# Length: 1720, dtype: int64

# %% [markdown]
# Sigh there are some contaminated gene names that have the AUC in them .. ahve to split the column

# %%
cluster_markers['gene_symbol'] = cluster_markers['gene_symbol'].str.split().str[0]
cluster_markers.groupby('gene_symbol').size()
# Out:
# gene_symbol
# 1500015O10RIK     1
# 1500016L03RIK     1
# 1700025G04RIK     1
# 1810009A15RIK     1
# 1810037I17RIK     1
# 2010107E04RIK     1
# 2410066E13RIK     1
# 2610017I09RIK     2
# 2900011O08RIK    11
# 4632428N05RIK     1
# 4833424O15RIK     4
# 4930447C04RIK     3
# 6330403K07RIK     7
# 6430548M08RIK    11
# 8430419L09RIK     1
# A030009H04RIK    13
# A330050F15RIK     1
# A730046J19RIK     2
# A830010M20RIK     2
# A830036E02RIK     1
# A930001A20RIK     1
# A930011O12RIK     7
# ABAT              2
# ABCA8A            1
# ABCB1A            1
# ABCC9             1
# ABCG2             1
# ABHD10            1
# ABHD2             1
# ABHD4             1
#                  ..
# VWC2              1
# VWF               1
# WASF2             1
# WBSCR17           1
# WDR1              3
# WFDC1             1
# WFDC10            1
# WIPI1             1
# WLS               2
# WNK4              1
# WWTR1             1
# YWHAB             2
# YWHAG             5
# YWHAH             6
# YWHAQ             1
# ZBTB20            1
# ZCCHC12           1
# ZCCHC18           5
# ZEB2              5
# ZFHX3             5
# ZFHX4             2
# ZFP36             1
# ZFP365            1
# ZFP36L1           2
# ZFP804A           8
# ZIC1              1
# ZIC4              1
# ZMAT4             2
# ZWINT             6
# ZYX               1
# Length: 1339, dtype: int64

# %% [markdown]
# ### Add columns to make pivotting (making a 2d matrix) easier

# %%
cluster_markers['cluster_name'] = 'retina_' \
    + cluster_markers['cluster #'].astype(str).str.zfill(2)
cluster_markers['in_cluster'] = True
cluster_markers.head()
# Out:
#   gene_symbol  myAUC    myDiff  power  cluster # cluster_name  in_cluster
# 0       CALB1  0.966  3.615047  0.466          1    retina_01        True
# 1      SLC4A3  0.963  3.448571  0.463          1    retina_01        True
# 2        TPM3  0.965  3.151521  0.465          1    retina_01        True
# 3       SEPT4  0.964  2.939258  0.464          1    retina_01        True
# 4         VIM  0.944  2.937992  0.444          1    retina_01        True

# %%
cluster_markers.groupby('cluster_name').size()
# Out:
# cluster_name
# retina_01    190
# retina_02    174
# retina_03    162
# retina_04     84
# retina_05    159
# retina_06    156
# retina_07    164
# retina_08    145
# retina_09    145
# retina_10    120
# retina_11    111
# retina_12     68
# retina_13    163
# retina_14    127
# retina_15     69
# retina_16     97
# retina_17     99
# retina_18     76
# retina_19    115
# retina_20     43
# retina_21     45
# retina_22     51
# retina_23     67
# retina_24     49
# retina_25     14
# retina_26     87
# retina_27     27
# retina_28     48
# retina_29     39
# retina_30     60
# retina_31     58
# retina_32     81
# retina_33     47
# retina_34    147
# retina_35    164
# retina_36    153
# retina_37    236
# retina_38    147
# retina_39    153
# dtype: int64

# %%
mouse_gene_metadata = cluster_markers.pivot(index='gene_symbol', 
                                      values='in_cluster',
                                      columns='cluster_name')
mouse_gene_metadata = mouse_gene_metadata.fillna(False)
mouse_gene_metadata.head()
# Out:
# cluster_name   retina_01  retina_02  retina_03  retina_04  retina_05  \
# gene_symbol
# 1500015O10RIK      False      False      False      False      False
# 1500016L03RIK       True      False      False      False      False
# 1700025G04RIK      False      False       True      False      False
# 1810009A15RIK      False      False      False      False      False
# 1810037I17RIK      False      False      False      False      False
#
# cluster_name   retina_06  retina_07  retina_08  retina_09  retina_10  \
# gene_symbol
# 1500015O10RIK      False      False      False      False      False
# 1500016L03RIK      False      False      False      False      False
# 1700025G04RIK      False      False      False      False      False
# 1810009A15RIK      False      False      False      False      False
# 1810037I17RIK      False      False      False      False      False
#
# cluster_name     ...      retina_30  retina_31  retina_32  retina_33  \
# gene_symbol      ...
# 1500015O10RIK    ...          False      False      False      False
# 1500016L03RIK    ...          False      False      False      False
# 1700025G04RIK    ...          False      False      False      False
# 1810009A15RIK    ...          False      False      False      False
# 1810037I17RIK    ...          False      False      False      False
#
# cluster_name   retina_34  retina_35  retina_36  retina_37  retina_38  \
# gene_symbol
# 1500015O10RIK      False       True      False      False      False
# 1500016L03RIK      False      False      False      False      False
# 1700025G04RIK      False      False      False      False      False
# 1810009A15RIK      False      False      False      False       True
# 1810037I17RIK      False       True      False      False      False
#
# cluster_name   retina_39
# gene_symbol
# 1500015O10RIK      False
# 1500016L03RIK      False
# 1700025G04RIK      False
# 1810009A15RIK      False
# 1810037I17RIK      False
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Pairwise markers
#
# These are the genes that distinguish sets of cells from each other.

# %%
filename = os.path.join(input_folder, 'mmc4_v2.xlsx')

pairwise_markers = pd.read_excel(filename,
                                sheetname='PAIRWISE_MARKERS_FINAL.txt')
print(pairwise_markers.shape)
pairwise_markers.head()
# Out:
# (193620, 3)
#   Unnamed: 0    Unnamed: 1 Unnamed: 2
# 0   Clusters           1+2        NaN
# 1        NaN           myP     myDiff
# 2        VIM  0.000000e+00   3.399495
# 3      NDRG1  0.000000e+00   3.258577
# 4      SEPT4  0.000000e+00   2.984931

# %% [markdown]
# This is a mess to clean ... each section is headed by the cluster numbers that are compared and have to iterate through every time you see "Clusters".
#
# Don't need this for now

# %% [markdown]
# ## Get cell cycle genes

# %%
filename = os.path.join(input_folder, 'mmc2.xlsx')
mmc2 = pd.read_excel(filename)
mmc2.head()
# Out:
#    cluster human gene  cluster.1 mouse gene  Unnamed: 4 Intersection  \
# 0      1.0      CCNE2          1      Shmt1         NaN    All genes
# 1      1.0       CDC6          1      Zmym1         NaN         ACTB
# 2      1.0      CLSPN          1      Meaf6         NaN      AKIRIN2
# 3      1.0        DTL          1      Usp37         NaN         ANLN
# 4      1.0       MCM3          1       Msh6         NaN       ANP32E
#
#       Unnamed: 6  Unnamed: 7
# 0    novel genes  annotation
# 1           ACTB         NaN
# 2      ARHGAP11A         NaN
# 3        ARL6IP6         NaN
# 4          ARPC2         NaN

# %% [markdown]
# This is a mix of both human and mouse data ... going to use just hte mouse ones for now

# %%
mouse_genes = mmc2[['cluster.1', 'mouse gene']]
mouse_genes['cluster.1'] = 'cellcycle_' + mouse_genes['cluster.1'].astype(str).str.zfill(2)
mouse_genes = mouse_genes.rename(columns={'cluster.1': 'cluster_name'})
mouse_genes['in_cluster'] = True
mouse_genes.head()
# Out:
# /Users/olgabot/anaconda3/envs/macosko2015-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    cluster_name mouse gene  in_cluster
# 0  cellcycle_01      Shmt1        True
# 1  cellcycle_01      Zmym1        True
# 2  cellcycle_01      Meaf6        True
# 3  cellcycle_01      Usp37        True
# 4  cellcycle_01       Msh6        True

# %%
csv = os.path.join(data_folder, 'cellcycle_genes_tidy.csv')
mouse_genes.to_csv(csv)
! ls -lh $csv
! head $csv
# Out:
# -rw-r--r--  1 olgabot  staff    21K Jun 26 11:22 ../data/04_extract_data_from_supplementary_excel_files/cellcycle_genes_tidy.csv
# ,cluster_name,mouse gene,in_cluster
# 0,cellcycle_01,    Shmt1,True
# 1,cellcycle_01,    Zmym1,True
# 2,cellcycle_01,    Meaf6,True
# 3,cellcycle_01,    Usp37,True
# 4,cellcycle_01,    Msh6,True
# 5,cellcycle_01,    Rbbp4,True
# 6,cellcycle_01,    Bri3bp,True
# 7,cellcycle_01,    Rrp8,True
# 8,cellcycle_01,    Mb21d1,True

# %%
cellcycle = mouse_genes.pivot(index='mouse gene', 
                              columns='cluster_name', 
                              values='in_cluster')
cellcycle = cellcycle.fillna(False)
cellcycle.head()
# Out:
# cluster_name  cellcycle_01  cellcycle_02  cellcycle_03  cellcycle_04  \
# mouse gene
#     Aaas             False         False         False         False
#     Acat2            False         False          True         False
#     Acot9            False         False         False         False
#     Actb             False         False         False         False
#     Adar             False         False         False         False
#
# cluster_name  cellcycle_05  cellcycle_06  cellcycle_07  cellcycle_08
# mouse gene
#     Aaas              True         False         False         False
#     Acat2            False         False         False         False
#     Acot9            False         False          True         False
#     Actb             False         False         False          True
#     Adar             False         False         False          True

# %% [markdown]
# ### Add to growing mouse metadata list

# %%
mouse_gene_metadata = pd.concat([mouse_gene_metadata, cellcycle], axis=1)
print(mouse_gene_metadata.shape)
mouse_gene_metadata.head()
# Out:
# (2007, 47)
# cluster_name retina_01 retina_02 retina_03 retina_04 retina_05 retina_06  \
#     Aaas           NaN       NaN       NaN       NaN       NaN       NaN
#     Acat2          NaN       NaN       NaN       NaN       NaN       NaN
#     Acot9          NaN       NaN       NaN       NaN       NaN       NaN
#     Actb           NaN       NaN       NaN       NaN       NaN       NaN
#     Adar           NaN       NaN       NaN       NaN       NaN       NaN
#
# cluster_name retina_07 retina_08 retina_09 retina_10     ...      retina_38  \
#     Aaas           NaN       NaN       NaN       NaN     ...            NaN
#     Acat2          NaN       NaN       NaN       NaN     ...            NaN
#     Acot9          NaN       NaN       NaN       NaN     ...            NaN
#     Actb           NaN       NaN       NaN       NaN     ...            NaN
#     Adar           NaN       NaN       NaN       NaN     ...            NaN
#
# cluster_name retina_39 cellcycle_01 cellcycle_02 cellcycle_03 cellcycle_04  \
#     Aaas           NaN        False        False        False        False
#     Acat2          NaN        False        False         True        False
#     Acot9          NaN        False        False        False        False
#     Actb           NaN        False        False        False        False
#     Adar           NaN        False        False        False        False
#
# cluster_name cellcycle_05 cellcycle_06 cellcycle_07 cellcycle_08
#     Aaas             True        False        False        False
#     Acat2           False        False        False        False
#     Acot9           False        False         True        False
#     Actb            False        False        False         True
#     Adar            False        False        False         True
#
# [5 rows x 47 columns]

# %%
mouse_gene_metadata = mouse_gene_metadata.fillna(False)
mouse_gene_metadata.head()
# Out:
# cluster_name  retina_01  retina_02  retina_03  retina_04  retina_05  \
#     Aaas          False      False      False      False      False
#     Acat2         False      False      False      False      False
#     Acot9         False      False      False      False      False
#     Actb          False      False      False      False      False
#     Adar          False      False      False      False      False
#
# cluster_name  retina_06  retina_07  retina_08  retina_09  retina_10  \
#     Aaas          False      False      False      False      False
#     Acat2         False      False      False      False      False
#     Acot9         False      False      False      False      False
#     Actb          False      False      False      False      False
#     Adar          False      False      False      False      False
#
# cluster_name      ...       retina_38  retina_39  cellcycle_01  cellcycle_02  \
#     Aaas          ...           False      False         False         False
#     Acat2         ...           False      False         False         False
#     Acot9         ...           False      False         False         False
#     Actb          ...           False      False         False         False
#     Adar          ...           False      False         False         False
#
# cluster_name  cellcycle_03  cellcycle_04  cellcycle_05  cellcycle_06  \
#     Aaas             False         False          True         False
#     Acat2             True         False         False         False
#     Acot9            False         False         False         False
#     Actb             False         False         False         False
#     Adar             False         False         False         False
#
# cluster_name  cellcycle_07  cellcycle_08
#     Aaas             False         False
#     Acat2            False         False
#     Acot9             True         False
#     Actb             False          True
#     Adar             False          True
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Add index name of gene symbol

# %%
mouse_gene_metadata.index.name = 'gene_symbol'

# %%
mouse_gene_metadata.head()
# Out:
# cluster_name  retina_01  retina_02  retina_03  retina_04  retina_05  \
# gene_symbol
#     Aaas          False      False      False      False      False
#     Acat2         False      False      False      False      False
#     Acot9         False      False      False      False      False
#     Actb          False      False      False      False      False
#     Adar          False      False      False      False      False
#
# cluster_name  retina_06  retina_07  retina_08  retina_09  retina_10  \
# gene_symbol
#     Aaas          False      False      False      False      False
#     Acat2         False      False      False      False      False
#     Acot9         False      False      False      False      False
#     Actb          False      False      False      False      False
#     Adar          False      False      False      False      False
#
# cluster_name      ...       retina_38  retina_39  cellcycle_01  cellcycle_02  \
# gene_symbol       ...
#     Aaas          ...           False      False         False         False
#     Acat2         ...           False      False         False         False
#     Acot9         ...           False      False         False         False
#     Actb          ...           False      False         False         False
#     Adar          ...           False      False         False         False
#
# cluster_name  cellcycle_03  cellcycle_04  cellcycle_05  cellcycle_06  \
# gene_symbol
#     Aaas             False         False          True         False
#     Acat2             True         False         False         False
#     Acot9            False         False         False         False
#     Actb             False         False         False         False
#     Adar             False         False         False         False
#
# cluster_name  cellcycle_07  cellcycle_08
# gene_symbol
#     Aaas             False         False
#     Acat2            False         False
#     Acot9             True         False
#     Actb             False          True
#     Adar             False          True
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Get annotated cell cycle genes

# %%
filename = os.path.join(input_folder, 'mmc2.xlsx')
mmc2 = pd.read_excel(filename, sheetname='Gene Sets Used in Analysis')
mmc2.head()
# Out:
#           G1/S             S          G2/M            M        M/G1
# 0          ACD         ABCC5          ANLN         AHI1       AGFG1
# 1        ACYP1        ABHD10         AP3D1      AKIRIN2      AGPAT3
# 2      ADAMTS1      ANKRD18A      ARHGAP19      ANKRD40      AKAP13
# 3      ANKRD10         ASF1B         ARL4A         ANLN        AMD1
# 4        APEX2         ATAD2         ARMC1       ANP32B      ANP32E

# %% [markdown]
# ## Write the gene metadata to csv

# %%
data_folder
# Out:
# '../data/04_extract_data_from_supplementary_excel_files'

# %%
csv = os.path.join(data_folder, 'mouse_gene_metadata.csv')
mouse_gene_metadata.to_csv(csv)
! head $csv
# Out:
# gene_symbol,retina_01,retina_02,retina_03,retina_04,retina_05,retina_06,retina_07,retina_08,retina_09,retina_10,retina_11,retina_12,retina_13,retina_14,retina_15,retina_16,retina_17,retina_18,retina_19,retina_20,retina_21,retina_22,retina_23,retina_24,retina_25,retina_26,retina_27,retina_28,retina_29,retina_30,retina_31,retina_32,retina_33,retina_34,retina_35,retina_36,retina_37,retina_38,retina_39,cellcycle_01,cellcycle_02,cellcycle_03,cellcycle_04,cellcycle_05,cellcycle_06,cellcycle_07,cellcycle_08
#     Aaas,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False
#     Acat2,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False
#     Acot9,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False
#     Actb,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True
#     Adar,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True
#     Adat2,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False
#     Add1,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False
#     Adprhl2,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False
#     Akap11,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,False,True,False,False,False,False,False
